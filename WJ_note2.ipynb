# %%
import numpy as np
import pandas as pd
import xlrd
import os
import seaborn as sns
import matplotlib.pyplot as plt 
from sklearn.model_selection import train_test_split, GridSearchCV,\
cross_val_score
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import BaggingClassifier, RandomForestClassifier,\
ExtraTreesClassifier, VotingClassifier, StackingRegressor
from sklearn.metrics import r2_score
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.impute import SimpleImputer
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import accuracy_score
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from imblearn.over_sampling import SMOTE
from sklearn.datasets import make_classification
from sklearn.decomposition import PCA

# %%
df = pd.read_csv("data/bigml_59c28831336c6604c800002a.csv")

# %%
df
# Out:
#      state  account length  area code phone number international plan  \
# 0       KS             128        415     382-4657                 no
# 1       OH             107        415     371-7191                 no
# 2       NJ             137        415     358-1921                 no
# 3       OH              84        408     375-9999                yes
# 4       OK              75        415     330-6626                yes
# ...    ...             ...        ...          ...                ...
# 3328    AZ             192        415     414-4276                 no
# 3329    WV              68        415     370-3271                 no
# 3330    RI              28        510     328-8230                 no
# 3331    CT             184        510     364-6381                yes
# 3332    TN              74        415     400-4344                 no
#
#      voice mail plan  number vmail messages  total day minutes  \
# ...

# %%
df['account length'].max()
# Out:
# 243

# %%
df["churn"].value_counts(normalize = True)
# Out:
# False    0.855086
# True     0.144914
# Name: churn, dtype: float64

# %%
data = df["churn"].value_counts()
#print (y)
sns.barplot(data.index, data.values)
# Out:
# C:\Users\wjsdn\AppData\Roaming\Python\Python39\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:>

# %%
df['target'] = df['churn'].replace(False, 0)
df['target'] = df['target'].replace(True, 1)

# %%
df[['customer service calls', 'churn']]
# Out:
#       customer service calls  churn
# 0                          1  False
# 1                          1  False
# 2                          0  False
# 3                          2  False
# 4                          3  False
# ...                      ...    ...
# 3328                       2  False
# 3329                       3  False
# 3330                       2  False
# 3331                       2  False
# 3332                       0  False
#
# [3333 rows x 2 columns]

# %%
df.groupby(['customer service calls','churn']).size()
# Out:
# customer service calls  churn
# 0                       False     605
#                         True       92
# 1                       False    1059
#                         True      122
# 2                       False     672
#                         True       87
# 3                       False     385
#                         True       44
# 4                       False      90
#                         True       76
# 5                       False      26
#                         True       40
# 6                       False       8
#                         True       14
# 7                       False       4
#                         True        5
# 8                       False       1
#                         True        1
# 9                       True        2
# dtype: int64

# %%
ax = df.groupby(['customer service calls','churn']).size().unstack().plot(kind='bar', stacked=True, figsize=(10,10)) 
ax.set_title("Number of Customers VS. Service Calls")
ax.set_ylabel("number of customers")
# Out:
# Text(0, 0.5, 'number of customers')

# %%
true_perc = df.groupby('customer service calls')['churn'].mean()*100
true_count = df.groupby('customer service calls')['churn'].sum()
false_count = df.groupby('customer service calls')['churn'].count() - df.groupby('customer service calls')['churn'].sum()

# final df
df_perc = pd.concat([false_count, true_count], axis=1)
df_perc.columns = ['churn', 'not churn']

# create plot
ax = df_perc.plot( kind='bar', stacked=True, figsize=(10,10))

# getting the  containers values
container_t = ax.containers[1]

# create custom labels 
labels = [f'{round(val, 2)} %' if  (val != 0) else '' for val in true_perc]

# annotate with the previous custom labels
ax.bar_label(container_t, labels=labels, fontsize=15)
ax.set_ylabel("number of customers")
ax.set_title("Number of Customers vs. Number of Customer Service Calls")

# pad the spacing between the number and the edge of the figure
ax.margins(y=0.1)

# show plot
plt.show()

# %%
fdf['churn'] = df['churn'].map({False:'no', True:'churn'})
fdf.groupby(['customer service calls','churn']).size()
# Out:
# customer service calls  churn
# 0                       churn      92
#                         no        605
# 1                       churn     122
#                         no       1059
# 2                       churn      87
#                         no        672
# 3                       churn      44
#                         no        385
# 4                       churn      76
#                         no         90
# 5                       churn      40
#                         no         26
# 6                       churn      14
#                         no          8
# 7                       churn       5
#                         no          4
# 8                       churn       1
#                         no          1
# 9                       churn       2
# dtype: int64

# %%
percentage_df = fdf.groupby(['customer service calls', 'churn']).size().groupby(level=0).apply(
    lambda x: np.round(100*x/x.sum(),2))



ax = percentage_df.unstack().plot(kind='bar', stacked=True, figsize=(20,10), color = ['#dc1c13', (0.1, 0.1, 0.1, 0.1)]) 
ax.set_title("Number of Customer Service Calls in Percantage", fontsize = 20)
ax.set_ylabel("Percentage", fontsize = 20)
ax.set_xlabel('Customer Service Calls', fontsize = 20)
ax.tick_params(axis='both', which='major', labelsize=15)
plt.xticks(rotation = 360)
for c in ax.containers:
    ax.bar_label(c, fmt='%.1f%%', label_type='center',color='black', fontsize = 15)

ax.legend(['Churn', 'No Churn'], bbox_to_anchor = (1,1), loc = "upper left", borderaxespad = .5, fontsize = 15)

# %%
ax2 = percentage_df.unstack().plot(kind='bar', stacked=True, figsize=(20,10), color = ['#dc1c13', (0.1, 0.1, 0.1, 0.1)]) 
ax2.set_title("Customer Churn rates increase 35% between 3 and 4 service calls", fontsize = 30, pad = 20)
ax2.set_ylabel("Percentage", fontsize = 20)
ax2.set_xlabel('Customer Service Calls', fontsize = 20)
ax2.tick_params(axis='both', which='major', labelsize=15)
plt.xticks(rotation = 360)
for c in ax.containers:
    ax2.bar_label(c, fmt='%.1f%%', label_type='center',color='black', fontsize = 15)

ax2.legend(['Churn', 'No Churn'], bbox_to_anchor = (1,1), loc = "upper left", borderaxespad = .5, fontsize = 15)

# %%
#fdf = df[['state', 'account length', 'international plan', 'voice mail plan', 'customer service calls', 'churn']]
fdf = df.copy()
fdf['international plan'] = df['international plan'].map({'no':0, 'yes':1})
fdf['voice mail plan'] = df['voice mail plan'].map({'no':0, 'yes':1})
fdf
# Out:
#      state  account length  area code phone number  international plan  \
# 0       KS             128        415     382-4657                   0
# 1       OH             107        415     371-7191                   0
# 2       NJ             137        415     358-1921                   0
# 3       OH              84        408     375-9999                   1
# 4       OK              75        415     330-6626                   1
# ...    ...             ...        ...          ...                 ...
# 3328    AZ             192        415     414-4276                   0
# 3329    WV              68        415     370-3271                   0
# 3330    RI              28        510     328-8230                   0
# 3331    CT             184        510     364-6381                   1
# 3332    TN              74        415     400-4344                   0
#
#       voice mail plan  number vmail messages  total day minutes  \
# ...

# %%
logreg = LogisticRegression(random_state=1)
X = fdf.drop(columns = ['churn', 'state', 'area code', 'phone number', 'target'])
y = fdf['churn']

#X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1, test_size = 0.5)
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 1)

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
model = LogisticRegression()
model.fit(X_train, y_train)
print(model.score(X_train, y_train))
# Out:
# 0.8647458983593438

# %%
print(model.score(X_test, y_test))
# Out:
# 0.8525179856115108

# %%
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score, roc_auc_score
def metrics(y_test,pred):
    accuracy = accuracy_score(y_test,pred)
    precision = precision_score(y_test,pred)
    recall = recall_score(y_test,pred)
    f1 = f1_score(y_test,pred)
    roc_score = roc_auc_score(y_test,pred,average='macro')
    print('accuracy : {0:.2f}, precision : {1:.2f}, recall : {2:.2f}'.format(accuracy,precision,recall))
    print('f1-score : {0:.2f}, auc : {1:.2f}'.format(f1,roc_score,recall))

# %%
pred = model.predict(X_test)
metrics(y_test, pred)
# Out:
# accuracy : 0.85, precision : 0.49, recall : 0.18
# f1-score : 0.26, auc : 0.57

# %%
y_train.value_counts()
# Out:
# False    2138
# True      361
# Name: churn, dtype: int64

# %%
print(model.coef_)
# Out:
# [[ 0.04127357  0.60008808 -0.69465213  0.26216961  0.34857118  0.04153828
#    0.34928219  0.18115282  0.03497036  0.18112691  0.10804293 -0.00477941
#    0.10633815  0.11609033 -0.33082399  0.11968273  0.72130739]]

# %%
smote = SMOTE(random_state = 1, sampling_strategy = 0.35)
X_train_over,y_train_over = smote.fit_resample(X_train,y_train)

# %%
smote_model = LogisticRegression()
smote_model.fit(X_train_over, y_train_over)
smote_pred = smote_model.predict(X_test)
metrics(y_test, smote_pred)
# Out:
# accuracy : 0.84, precision : 0.43, recall : 0.36
# f1-score : 0.39, auc : 0.64

# %%
y_train_over.value_counts() / len(y_train_over)
# Out:
# False    0.740818
# True     0.259182
# Name: churn, dtype: float64

# %%
df_churn_no_churn = df.copy()
def categorise(row):
    if row['churn'] == 1:
        return "churn"
    else:
        return 'no churn'
df_churn_no_churn["churn_no_churn"] = df.apply(lambda row: categorise(row), axis =1)
fig, ax = plt.subplots(figsize=(15,8))
plt.title('Distribution of Total Day Charge', fontsize = 25)
sns.scatterplot(x="churn_no_churn",y="total day charge", data = df_churn_no_churn)
ax.axhline(54.03)
ax.tick_params(axis = 'both', labelsize = 15)
plt.xlabel('Total Day Charge', fontsize = 20)
ax.axhline(54.03, color = 'red')
plt.tight_layout()

# %%
# plot and visualize based on International plan

fig, ax = plt.subplots(figsize=(10,8))

sns.barplot(x = 'international plan', y = 'churn', data = df.groupby('international plan').mean().reset_index(), ax = ax)

for bar in ax.patches:
    if bar.get_height() > .2:
        bar.set_color('#dc1c13')    
    else:
        bar.set_color('#E7E7E7')
plt.title('Percentage of Customer Churn for International Plan Holders', fontsize = 25, pad = 20)

ax.tick_params(axis = 'both', labelsize = 15)

plt.xlabel('International Plan True/False', fontsize = 20)

plt.ylabel('Churn Rate', fontsize = 20)

ax.set_xticklabels(['No International Plan', 'Has International Plan'])

plt.tight_layout()

#plt.savefig('img/International_Plan_Churn.png', bbox_inches = "tight")

# %%
# plot and visualize based on International plan

fig, ax = plt.subplots(figsize=(10,8))

sns.barplot(x = 'international plan', y = 'churn', data = df.groupby('international plan').mean().reset_index(), ax = ax)

for bar in ax.patches:
    if bar.get_height() > .2:
        bar.set_color('#dc1c13')    
    else:
        bar.set_color('#E7E7E7')
plt.title('42% of Customers with an International Plan Churn', fontsize = 30, pad = 20)

ax.tick_params(axis = 'both', labelsize = 15)

plt.xlabel('International Plan True/False', fontsize = 20)

plt.ylabel('Churn Rate', fontsize = 20)

ax.set_xticklabels(['No International Plan', 'Has International Plan'])

plt.tight_layout()
